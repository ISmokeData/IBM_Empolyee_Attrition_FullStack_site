# %% [markdown]
# ### **Data**
# Here’s a brief explanation of the columns in the **Attrition** dataset:
#
# 1. **Age**: The age of the employee.
# 2. **Attrition**: Whether the employee has left the company (Yes/No).
# 3. **BusinessTravel**: Frequency of employee's business travel (e.g., Non-Travel, Travel_Rarely, Travel_Frequently).
# 4. **DailyRate**: Daily salary of the employee.
# 5. **Department**: The department the employee works in (e.g., Sales, R&D, HR).
# 6. **DistanceFromHome**: The distance between the employee's home and workplace.
# 7. **Education**: Education level (numerical, typically from 1 to 5).
# 8. **EducationField**: The field of education (e.g., Life Sciences, Marketing).
# 9. **EmployeeCount**: Typically a constant column with the value 1 (used for counting employees).
# 10. **EmployeeNumber**: Unique identifier for each employee.
# 11. **EnvironmentSatisfaction**: Satisfaction level with the workplace environment (1 to 4).
# 12. **Gender**: Gender of the employee (Male/Female).
# 13. **HourlyRate**: Hourly wage of the employee.
# 14. **JobInvolvement**: Level of involvement in their job (1 to 4).
# 15. **JobLevel**: Level of the job position (1 to 5).
# 16. **JobRole**: The employee's job role (e.g., Sales Executive, Research Scientist).
# 17. **JobSatisfaction**: Satisfaction with the job (1 to 4).
# 18. **MaritalStatus**: Marital status (e.g., Single, Married, Divorced).
# 19. **MonthlyIncome**: Monthly salary of the employee.
# 20. **MonthlyRate**: Monthly rate of pay.
# 21. **NumCompaniesWorked**: Number of companies the employee has worked at.
# 22. **Over18**: Whether the employee is over 18 (usually always "Yes").
# 23. **OverTime**: Whether the employee works overtime (Yes/No).
# 24. **PercentSalaryHike**: Percentage increase in salary.
# 25. **PerformanceRating**: Employee's performance rating (1 to 4).
# 26. **RelationshipSatisfaction**: Satisfaction with relationships at work (1 to 4).
# 27. **StandardHours**: Standard working hours (typically 40).
# 28. **StockOptionLevel**: Level of stock options granted (0 to 3).
# 29. **TotalWorkingYears**: Total years the employee has worked.
# 30. **TrainingTimesLastYear**: Number of training sessions attended last year.
# 31. **WorkLifeBalance**: Work-life balance rating (1 to 4).
# 32. **YearsAtCompany**: Total years the employee has been at the current company.
# 33. **YearsInCurrentRole**: Total years the employee has been in their current role.
# 34. **YearsSinceLastPromotion**: Years since the employee's last promotion.
# 35. **YearsWithCurrManager**: Total years the employee has worked with their current manager.
#
# ### Education
# - 1 'Below College'
# - 2 'College'
# - 3 'Bachelor'
# - 4 'Master'
# - 5 'Doctor'
#
# ### EnvironmentSatisfaction
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# ### JobInvolvement
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# ### JobSatisfaction
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# ### PerformanceRating
# - 1 'Low'
# - 2 'Good'
# - 3 'Excellent'
# - 4 'Outstanding'
#
# ### RelationshipSatisfaction
# - 1 'Low'
# - 2 'Medium'
# - 3 'High'
# - 4 'Very High'
#
# ### WorkLifeBalance
# - 1 'Bad'
# - 2 'Good'
# - 3 'Better'
# - 4 'Best'

# %% [markdown]
# ### **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Dataz/attrition.csv')

# %%
df = dataset.copy()

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
cat = df.select_dtypes(include='object').columns

# %%
num = df.select_dtypes(include='int').columns

# %% [markdown]
# # **Task**
# 1. `Education`, `JobLevel`, `JobSatisfaction`, `NumCompaniesWorked`, `PercentSalaryHike`, `PerformanceRating`, `RelationshipSatisfaction`,`StockOptionLevel`, `TotalWorkingYears`, `TrainingTimesLastYear`, `WorkLifeBalance`, `YearsSinceLastPromotion`, `YearsAtCompany`, `YearsInCurrentRole`, `YearsWithCurrManager` is object
# 2. Drop `EmployeeCount` (only single value -> 1), `StandardHours` (only single value - 80), `Over18` (only single value - y)

# %%
df['YearsWithCurrManager'].value_counts()
# Out:
# YearsWithCurrManager
# 2     344
# 0     263
# 7     216
# 3     142
# 8     107
# 4      98
# 1      76
# 9      64
# 5      31
# 6      29
# 10     27
# 11     22
# 12     18
# 13     14
# 17      7
# 15      5
# 14      5
# 16      2
# Name: count, dtype: int64

# %% [markdown]
# # **EDA**

# %% [markdown]
# ## **Univariate Analysis**

# %%
sns.displot(df, x="Age", kind="kde", fill=True);
plt.title('Age Distribution');
plt.xlabel('Age');
plt.ylabel('Count');

# %% [markdown]
# ### **Age-** Normal Distribution (symmetric)

# %%
sns.displot(df, x="DailyRate", kind="kde", fill=True,color = 'orange');
plt.title('DailyRoute Distribution');
plt.xlabel('DailyRoute');
plt.ylabel('Count');

# %% [markdown]
# ## **DailyRoute-** Bimodel (non -symmetric)

# %%
sns.displot(df, x="DistanceFromHome", kind="kde", fill=True, color= 'green');
plt.title('DistanceFromHome Distribution');
plt.xlabel('DistanceFromHome');
plt.ylabel('Count');

# %% [markdown]
# ## **DistanceFromHome-** Right Skewed Distribution (Positive Skewed)

# %%
sns.displot(df, x="EmployeeNumber", kind="kde", fill=True, color= 'yellow',bw_adjust=.80);
plt.title('EmployeeNumber Distribution');
plt.xlabel('EmployeeNumber');
plt.ylabel('Count');

# %% [markdown]
# ## **Employee Number - non symmetric bimodel distribution**

# %%
sns.displot(df, x="HourlyRate", kind="kde", fill=True, color= 'red');
plt.title('HourlyRate Distribution');
plt.xlabel('HourlyRate');
plt.ylabel('Count');

# %% [markdown]
# ## **HourlyRate -** non symmetric bimodel distribution

# %%
sns.displot(df, x="MonthlyIncome", kind="kde", fill=True, color= 'black');
plt.title('MonthlyIncome Distribution');
plt.xlabel('MonthlyIncome');
plt.ylabel('Count');

# %% [markdown]
# ## **MonthlyIncome-** Right Skewed Distribution

# %%
sns.displot(df, x="MonthlyRate", kde = True, fill=True, color= 'brown');
plt.title('MonthlyRate Distribution');
plt.xlabel('MonthlyRate');
plt.ylabel('Count');

# %% [markdown]
# ## **MonthlyRate-** Symmetric bimodel distribution

# %%
sns.displot(df, x="PercentSalaryHike", kind="kde", fill=True, color= 'purple');
plt.title('PercentSalaryHike Distribution');
plt.xlabel('PercentSalaryHike');
plt.ylabel('Count');

# %% [markdown]
# ## **PercentSalaryHike -** Right Skewed Distribution

# %%
sns.displot(df, x="TotalWorkingYears", kind="kde", fill=True, color= 'orange');
plt.title('TotalWorkingYears Distribution');
plt.xlabel('TotalWorkingYears');
plt.ylabel('Count');

# %% [markdown]
# ## **TotalWorkingYears -** right skewed

# %%
sns.displot(df, x="YearsAtCompany", kde = True, fill=True, color= 'green');
plt.title('YearsAtCompany Distribution');
plt.xlabel('YearsAtCompany');
plt.ylabel('Count');

# %% [markdown]
# ## **YearsAtCompany -** right skewed

# %%
sns.displot(df, x="YearsInCurrentRole", kde = True, fill=True, color= 'blue');
plt.title('YearsInCurrentRole Distribution');
plt.xlabel('YearsInCurrentRole');
plt.ylabel('Count');

# %% [markdown]
# ## **YearsInCurrentRole -** Non-symmetric Bimodel Distribution

# %%
sns.displot(df, x="YearsSinceLastPromotion", kde = True, fill=True, color= 'black');
plt.title('YearsSinceLastPromotion Distribution');
plt.xlabel('YearsSinceLastPromotion');
plt.ylabel('Count');

# %% [markdown]
# ## **YearsSinceLastPromotion -** Right Skewed

# %%
sns.displot(df, x="YearsWithCurrManager", kde = True, fill=True, color= 'brown');
plt.title('YearsWithCurrManager Distribution');
plt.xlabel('YearsWithCurrManager');
plt.ylabel('Count');

# %% [markdown]
# ## **YearsWithCurrManager -** Non-symmetric bimodel distribution

# %%
sns.displot(df, x="Attrition", fill=True, color= 'blue');
plt.title('Attrition Distribution');
plt.xlabel('Attrition');
plt.ylabel('Count');

# %%
sns.displot(df, x="BusinessTravel", fill=True, color= 'green');
plt.title('BusinessTravel Distribution');
plt.xlabel('BusinessTravel');
plt.ylabel('Count');
plt.xticks(rotation=90);

# %%
sns.displot(df, x="Department", fill=True, color= 'green');
plt.title('Department Distribution');
plt.xlabel('Department');
plt.ylabel('Count');
plt.xticks(rotation=90);

# %%
sns.displot(df, x="EducationField", fill=True, color= 'green');
plt.title('EducationField Distribution');
plt.xlabel('EducationField');
plt.ylabel('Count');
plt.xticks(rotation=90);

# %%
sns.displot(df, x="Gender", fill=True, color= 'black');
plt.title('Gender Distribution');
plt.xlabel('Gender');
plt.ylabel('Count');
plt.xticks(rotation=90);

# %% [markdown]
# 'JobRole', 'MaritalStatus', 'Over18', 'OverTime'

# %%
attrition_rate = df["Attrition"].value_counts()
plt.subplot(1,2,2)
colors = sns.color_palette('Set2', len(attrition_rate))
plt.pie(attrition_rate, labels=["No","Yes"], autopct="%.2f%%", textprops={"size":14},
        colors = colors,explode=[0,0.1],startangle=140)
center_circle = plt.Circle((0, 0), 0.3, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
plt.title("Employee Attrition Rate",fontweight="black",size=14 ,pad=15)
plt.show()

# %%
sns.displot(df, x="JobRole", fill=True, color= 'black');
plt.title('JobRole Distribution');
plt.xlabel('JobRole');
plt.ylabel('Count');
plt.xticks(rotation=90);

sns.displot(df, x="MaritalStatus", fill=True, color= 'green');
plt.title('MaritalStatus Distribution');
plt.xlabel('MaritalStatus');
plt.ylabel('Count');
plt.xticks(rotation=90);

sns.displot(df, x="Over18", fill=True, color= 'blue');
plt.title('Over18 Distribution');
plt.xlabel('Over18');
plt.ylabel('Count');
plt.xticks(rotation=90);

sns.displot(df, x="OverTime", fill=True, color= 'orange');
plt.title('OverTime Distribution');
plt.xlabel('OverTime');
plt.ylabel('Count');
plt.xticks(rotation=90);

# %%
attrition_rate = df["Attrition"].value_counts()
plt.subplot(1,2,2)
colors = sns.color_palette('Set2', len(attrition_rate))
plt.pie(attrition_rate, labels=["No","Yes"], autopct="%.2f%%", textprops={"size":14},
        colors = colors,explode=[0,0.1],startangle=140)
center_circle = plt.Circle((0, 0), 0.3, fc='white')
fig = plt.gcf()
fig.gca().add_artist(center_circle)
plt.title("Employee Attrition Rate",fontweight="black",size=14 ,pad=15)
plt.show()

# %% [markdown]
# ---
# # **Multivariate Analysis**

# %%
num
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'NumCompaniesWorked', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## **Age, DailyRate, Attrition**

# %%
sns.scatterplot(data = df, x = 'Age', y= 'DailyRate')
# Out:
# <Axes: xlabel='Age', ylabel='DailyRate'>

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue="Attrition", col="Attrition", height=4)
g.map(hexbin, "Age", "DailyRate");

# %% [markdown]
# ## **Age, DistanceFromHome, Attrition**

# %%
sns.scatterplot(data = df, x = 'Age', y= 'DistanceFromHome', color = 'green')
# Out:
# <Axes: xlabel='Age', ylabel='DistanceFromHome'>

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue="Attrition", col="Attrition", height=4)
g.map(hexbin, "Age", "DistanceFromHome");

# %% [markdown]
# ## **Age, EmployeeNumber, Attrition**

# %%
sns.scatterplot(data = df, x = 'Age', y= 'EmployeeNumber', color = 'purple')
# Out:
# <Axes: xlabel='Age', ylabel='EmployeeNumber'>

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue="Attrition", col="Attrition", height=4)
g.map(hexbin, "Age", "EmployeeNumber");

# %% [markdown]
# ## **Age, MonthlyIncome, Attrition**

# %%
sns.scatterplot(data = df, x = 'Age', y= 'MonthlyIncome', color = 'pink')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue="Attrition", col="Attrition", height=4)
g.map(hexbin, "Age", "MonthlyIncome");

# %% [markdown]
# ## **Age, MonthlyRate, Attrition**

# %%
sns.scatterplot(data = df, x = 'Age', y= 'MonthlyRate', color = 'grey')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyRate'>

# %%
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color, as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)

with sns.axes_style("dark"):
    g = sns.FacetGrid(df, hue="Attrition", col="Attrition", height=4)
g.map(hexbin, "Age", "MonthlyRate");

# %% [markdown]
# ## **Not correlated**

# %%
df.corr(numeric_only=True)
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %% [markdown]
# ## **Education**
# - 1 'Below College'
# - 2 'College'
# - 3 'Bachelor'
# - 4 'Master'
# - 5 'Doctor'

# %%
sns.displot(df, x="Education", fill=True, color= 'green', hue= 'Attrition');
plt.title('Education Distribution');
plt.xlabel('Education');
plt.ylabel('Count');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.barplot(data = df, x = 'Education', y= 'Age', hue='Attrition');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# - **Attrition (NO) -> All Education -> Age -> between 30 and 40**
# - **Attrition (Yes) -> All Education -> Age -> between 28 and 35**

# %%
sns.barplot(data = df, x = 'Education', y= 'DailyRate', hue='Attrition');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# - **Attrition (NO) -> All Education -> DailyRate -> 780 and 820**
# - **Attrition (Yes) -> All Education -> DailyRate -> 790 and 830**

# %%
sns.displot(df, x="EnvironmentSatisfaction", fill=True, color= 'green', hue= 'Attrition');
plt.title('EnvironmentSatisfaction Distribution');
plt.xlabel('EnvironmentSatisfaction');
plt.ylabel('Count');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.barplot(data = df, x = 'Education', y= 'EnvironmentSatisfaction', hue='Attrition');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# Education, JobLevel, JobSatisfaction, NumCompaniesWorked, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction,StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsSinceLastPromotion, YearsAtCompany, YearsInCurrentRole, YearsWithCurrManager is object

# %%
sns.displot(df, x="NumCompaniesWorked", fill=True, color= 'green', hue= 'Attrition');
plt.title('NumCompaniesWorked Distribution');
plt.xlabel('NumCompaniesWorked');
plt.ylabel('Count');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %%
sns.barplot(data = df, x = 'Education', y= 'NumCompaniesWorked', hue='Attrition');
plt.title('NumCompaniesWorked - Education Distribution');
plt.xlabel('Education');
plt.ylabel('NumCompaniesWorked');
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
